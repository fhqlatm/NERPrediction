# %%
import os
import json
from functools import partial
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim import AdamW
from transformers import BertTokenizer
from transformers import BertModel
from sklearn.metrics import classification_report

# %%
from dataset import Dataset_NER, ner_collate_fn
from tag_id_converter import Tag_ID_Converter

# %%
PRETAINED_MODEL_NAME = 'bert-base-multilingual-cased'
tokenizer = BertTokenizer.from_pretrained(PRETAINED_MODEL_NAME)
bert = BertModel.from_pretrained(PRETAINED_MODEL_NAME)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
PATH_dir = '../data/en_ner_data'
# PATH_dir = '../0_data/En_NER_POS'
PATH_en_train = os.path.join(PATH_dir, 'prepro_train.json')
PATH_en_test = os.path.join(PATH_dir, 'prepro_test.json')
PATH_en_valid = os.path.join(PATH_dir, 'prepro_valid.json')
# PATH_ko_dev = os.path.join(PATH_dir, 'prepro_valid.json')
# PATH_tag_cnt_dict = os.path.join(PATH_dir, 'prepro_tag_cnt.json')

# %%
dataset_train = Dataset_NER(PATH_en_train)
dataset_test = Dataset_NER(PATH_en_test)
dataset_valid = Dataset_NER(PATH_en_valid)

# %%
print(
		len(dataset_train),
		len(dataset_test),
		len(dataset_valid)
	)
# Out:
# 14987 3684 3466

# %%
tag_converter = Tag_ID_Converter(PATH_dir, ['prepro_train_tag_list.json', 'prepro_test_tag_list.json', 'prepro_valid_tag_list.json'])

# %%
tag_converter.id_to_tag
# Out:
# {0: '[PAD]',
#  1: 'I-ORG',
#  2: 'B-LOC',
#  3: 'I-LOC',
#  4: 'B-PER',
#  5: 'O',
#  6: 'B-MISC',
#  7: 'I-MISC',
#  8: 'B-ORG',
#  9: 'I-PER'}

# %%
tag_converter.tag_to_id
# Out:
# {'[PAD]': 0,
#  'I-ORG': 1,
#  'B-LOC': 2,
#  'I-LOC': 3,
#  'B-PER': 4,
#  'O': 5,
#  'B-MISC': 6,
#  'I-MISC': 7,
#  'B-ORG': 8,
#  'I-PER': 9}

# %%
batch_size = 16
partial_collate_fn = partial(ner_collate_fn, tokenizer, tag_converter)

# %%
dataloader_train = DataLoader(
    dataset_train,
    batch_size=batch_size,
    shuffle=True,
    collate_fn=partial_collate_fn
)
dataloader_test = DataLoader(
    dataset_test,
    batch_size=batch_size,
    shuffle=False,
    collate_fn=partial_collate_fn
)
dataloader_valid = DataLoader(
    dataset_valid,
    batch_size=batch_size,
    shuffle=False,
    collate_fn=partial_collate_fn
)

# %%
class Bert_NER(nn.Module):

    def __init__(self, bert, output):
        super().__init__()
        self.bert = bert
        self.dropout = nn.Dropout(p = 0.1)
        self.lin = nn.Linear(768, output)
        self.softmax = nn.Softmax(2)

    def forward(self,**kargs):
        emb = self.bert(**kargs)
        e = self.dropout(emb['last_hidden_state'])
        w = self.lin(e)
        return w

# %%
tag_len = len(tag_converter.tag_to_id)
model = Bert_NER(bert, tag_len)

# %%
CELoss = nn.CrossEntropyLoss(ignore_index=0)
optimizer = AdamW(model.parameters(), lr=1.0e-5)

# %%
model.cuda(1)
device = model.bert.device
device
# Out:
# device(type='cuda', index=1)

# %%
train_epoch = 5
grad_accumulation_steps = 8

# %%
for epoch in range(train_epoch):
    model.train()

    for iteration, batch in enumerate(dataloader_train):
        batch_inputs = {k: v.cuda(device) for k, v in list(batch[0].items())}
        batch_labels = batch[1].cuda(device)

        output = model(**batch_inputs)
        loss = CELoss(output.view(-1, output.size(-1)), batch_labels.view(-1))

        loss.backward()

        if (iteration + 1) % grad_accumulation_steps == 0:
            optimizer.step()
            optimizer.zero_grad()
            print(f'epoch - {epoch}: update step {(iteration + 1) // grad_accumulation_steps}')
            print(f'{iteration + 1} - loss: {loss.item()}')

    print(f'epoch {epoch} END')
# Out:
# epoch - 0: update step 1
# 10 - loss: 2.2721500396728516
# epoch - 0: update step 2
# 20 - loss: 1.8595995903015137
# epoch - 0: update step 3
# 30 - loss: 1.5840789079666138
# epoch - 0: update step 4
# 40 - loss: 1.284036636352539
# epoch - 0: update step 5
# epoch - 0: update step 6
# 50 - loss: 1.2129381895065308
# epoch - 0: update step 7
# 60 - loss: 0.9315145611763
# epoch - 0: update step 8
# 70 - loss: 0.9551402926445007
# epoch - 0: update step 9
# 80 - loss: 0.8640445470809937
# epoch - 0: update step 10
# epoch - 0: update step 11
# 90 - loss: 0.747524082660675
# epoch - 0: update step 12
# 100 - loss: 0.9073916077613831
# epoch - 0: update step 13
# 110 - loss: 0.8516948223114014
# epoch - 0: update step 14
# 120 - loss: 1.044482946395874
# epoch - 0: update step 15
# epoch - 0: update step 16
# 130 - loss: 0.6896594166755676
# epoch - 0: update step 17
# 140 - loss: 0.7908639311790466
# epoch - 0: update step 18
# 150 - loss: 0.711876392364502
# epoch - 0: update step 19
# 160 - loss: 0.9316486716270447
# epoch - 0: update step 20
# epoch - 0: update step 21
# 170 - loss: 0.7344414591789246
# epoch - 0: update step 22
# 180 - loss: 0.7570033669471741
# epoch - 0: update step 23
# 190 - loss: 0.7063485383987427
# epoch - 0: update step 24
# 200 - loss: 0.5742877125740051
# epoch - 0: update step 25
# epoch - 0: update step 26
# 210 - loss: 0.8116171956062317
# epoch - 0: update step 27
# 220 - loss: 0.7438136339187622
# epoch - 0: update step 28
# 230 - loss: 0.6201735734939575
# epoch - 0: update step 29
# 240 - loss: 0.656920313835144
# epoch - 0: update step 30
# epoch - 0: update step 31
# 250 - loss: 0.6207064986228943
# epoch - 0: update step 32
# 260 - loss: 0.5807496905326843
# epoch - 0: update step 33
# 270 - loss: 0.3951738178730011
# epoch - 0: update step 34
# 280 - loss: 0.6177136301994324
# epoch - 0: update step 35
# epoch - 0: update step 36
# 290 - loss: 0.6373558640480042
# epoch - 0: update step 37
# 300 - loss: 0.4965382516384125
# epoch - 0: update step 38
# 310 - loss: 0.7107938528060913
# epoch - 0: update step 39
# 320 - loss: 0.4181964695453644
# epoch - 0: update step 40
# epoch - 0: update step 41
# 330 - loss: 0.601630687713623
# epoch - 0: update step 42
# 340 - loss: 0.33505669236183167
# epoch - 0: update step 43
# 350 - loss: 0.5802305340766907
# epoch - 0: update step 44
# 360 - loss: 0.363869845867157
# epoch - 0: update step 45
# epoch - 0: update step 46
# 370 - loss: 0.6582737565040588
# epoch - 0: update step 47
# 380 - loss: 0.5407138466835022
# epoch - 0: update step 48
# 390 - loss: 0.37325868010520935
# epoch - 0: update step 49
# 400 - loss: 0.47915729880332947
# epoch - 0: update step 50
# epoch - 0: update step 51
# 410 - loss: 0.43565309047698975
# epoch - 0: update step 52
# 420 - loss: 0.41013669967651367
# epoch - 0: update step 53
# 430 - loss: 0.4543202221393585
# epoch - 0: update step 54
# 440 - loss: 0.3114132285118103
# epoch - 0: update step 55
# epoch - 0: update step 56
# 450 - loss: 0.4360792934894562
# epoch - 0: update step 57
# 460 - loss: 0.4299135208129883
# epoch - 0: update step 58
# 470 - loss: 0.3177736699581146
# epoch - 0: update step 59
# 480 - loss: 0.43509864807128906
# epoch - 0: update step 60
# epoch - 0: update step 61
# 490 - loss: 0.5380248427391052
# epoch - 0: update step 62
# 500 - loss: 0.3329119384288788
# epoch - 0: update step 63
# 510 - loss: 0.34752798080444336
# epoch - 0: update step 64
# 520 - loss: 0.4402720630168915
# epoch - 0: update step 65
# epoch - 0: update step 66
# 530 - loss: 0.3598942458629608
# epoch - 0: update step 67
# 540 - loss: 0.2811678647994995
# epoch - 0: update step 68
# 550 - loss: 0.25798654556274414
# epoch - 0: update step 69
# 560 - loss: 0.31375405192375183
# epoch - 0: update step 70
# epoch - 0: update step 71
# 570 - loss: 0.5577604174613953
# epoch - 0: update step 72
# 580 - loss: 0.34460774064064026
# epoch - 0: update step 73
# 590 - loss: 0.5486031770706177
# epoch - 0: update step 74
# 600 - loss: 0.2940206527709961
# epoch - 0: update step 75
# epoch - 0: update step 76
# 610 - loss: 0.4459729790687561
# epoch - 0: update step 77
# 620 - loss: 0.2345227301120758
# epoch - 0: update step 78
# 630 - loss: 0.21366570889949799
# epoch - 0: update step 79
# 640 - loss: 0.40059730410575867
# epoch - 0: update step 80
# epoch - 0: update step 81
# 650 - loss: 0.26813897490501404
# epoch - 0: update step 82
# 660 - loss: 0.26403871178627014
# epoch - 0: update step 83
# 670 - loss: 0.634053111076355
# epoch - 0: update step 84
# 680 - loss: 0.19708804786205292
# epoch - 0: update step 85
# epoch - 0: update step 86
# 690 - loss: 0.34276100993156433
# epoch - 0: update step 87
# 700 - loss: 0.2112780213356018
# epoch - 0: update step 88
# 710 - loss: 0.27274614572525024
# epoch - 0: update step 89
# 720 - loss: 0.18225549161434174
# epoch - 0: update step 90
# epoch - 0: update step 91
# 730 - loss: 0.1732708066701889
# epoch - 0: update step 92
# 740 - loss: 0.5544846653938293
# epoch - 0: update step 93
# 750 - loss: 0.2883644700050354
# epoch - 0: update step 94
# 760 - loss: 0.24694274365901947
# epoch - 0: update step 95
# epoch - 0: update step 96
# 770 - loss: 0.20017953217029572
# epoch - 0: update step 97
# 780 - loss: 0.2536486089229584
# epoch - 0: update step 98
# 790 - loss: 0.250439316034317
# epoch - 0: update step 99
# 800 - loss: 0.16514936089515686
# epoch - 0: update step 100
# epoch - 0: update step 101
# 810 - loss: 0.33350780606269836
# epoch - 0: update step 102
# 820 - loss: 0.1716400682926178
# epoch - 0: update step 103
# 830 - loss: 0.2238038331270218
# epoch - 0: update step 104
# 840 - loss: 0.15657995641231537
# epoch - 0: update step 105
# epoch - 0: update step 106
# 850 - loss: 0.2654154300689697
# epoch - 0: update step 107
# 860 - loss: 0.20164240896701813
# epoch - 0: update step 108
# 870 - loss: 0.15934081375598907
# epoch - 0: update step 109
# 880 - loss: 0.2799282670021057
# epoch - 0: update step 110
# epoch - 0: update step 111
# 890 - loss: 0.2836650013923645
# epoch - 0: update step 112
# 900 - loss: 0.23760241270065308
# epoch - 0: update step 113
# 910 - loss: 0.18090391159057617
# epoch - 0: update step 114
# 920 - loss: 0.2833160161972046
# epoch - 0: update step 115
# epoch - 0: update step 116
# 930 - loss: 0.16408130526542664
# epoch - 0: update step 117
# epoch 0 END
# epoch - 1: update step 1
# 10 - loss: 0.23410291969776154
# epoch - 1: update step 2
# 20 - loss: 0.1550627052783966
# epoch - 1: update step 3
# 30 - loss: 0.3725065290927887
# epoch - 1: update step 4
# 40 - loss: 0.14861883223056793
# epoch - 1: update step 5
# epoch - 1: update step 6
# 50 - loss: 0.15760309994220734
# epoch - 1: update step 7
# 60 - loss: 0.1567079722881317
# epoch - 1: update step 8
# 70 - loss: 0.19232842326164246
# epoch - 1: update step 9
# 80 - loss: 0.2741183340549469
# epoch - 1: update step 10
# epoch - 1: update step 11
# 90 - loss: 0.19077694416046143
# epoch - 1: update step 12
# 100 - loss: 0.20991013944149017
# epoch - 1: update step 13
# 110 - loss: 0.1071176752448082
# epoch - 1: update step 14
# 120 - loss: 0.08513560146093369
# epoch - 1: update step 15
# epoch - 1: update step 16
# 130 - loss: 0.3397938013076782
# epoch - 1: update step 17
# 140 - loss: 0.14066456258296967
# epoch - 1: update step 18
# 150 - loss: 0.1553839147090912
# epoch - 1: update step 19
# 160 - loss: 0.12001609057188034
# epoch - 1: update step 20
# epoch - 1: update step 21
# 170 - loss: 0.1313369870185852
# epoch - 1: update step 22
# 180 - loss: 0.10295763611793518
# epoch - 1: update step 23
# 190 - loss: 0.15922772884368896
# epoch - 1: update step 24
# 200 - loss: 0.10626234114170074
# epoch - 1: update step 25
# epoch - 1: update step 26
# 210 - loss: 0.25290969014167786
# epoch - 1: update step 27
# 220 - loss: 0.23857282102108002
# epoch - 1: update step 28
# 230 - loss: 0.13092631101608276
# epoch - 1: update step 29
# 240 - loss: 0.1198236495256424
# epoch - 1: update step 30
# epoch - 1: update step 31
# 250 - loss: 0.07832730561494827
# epoch - 1: update step 32
# 260 - loss: 0.21635013818740845
# epoch - 1: update step 33
# 270 - loss: 0.07621730864048004
# epoch - 1: update step 34
# 280 - loss: 0.22099436819553375
# epoch - 1: update step 35
# epoch - 1: update step 36
# 290 - loss: 0.0771968737244606
# epoch - 1: update step 37
# 300 - loss: 0.10540644824504852
# epoch - 1: update step 38
# 310 - loss: 0.1279657632112503
# epoch - 1: update step 39
# 320 - loss: 0.1977439969778061
# epoch - 1: update step 40
# epoch - 1: update step 41
# 330 - loss: 0.076230488717556
# epoch - 1: update step 42
# 340 - loss: 0.09570502489805222
# epoch - 1: update step 43
# 350 - loss: 0.10433416068553925
# epoch - 1: update step 44
# 360 - loss: 0.18939946591854095
# epoch - 1: update step 45
# epoch - 1: update step 46
# 370 - loss: 0.14787648618221283
# epoch - 1: update step 47
# 380 - loss: 0.16386856138706207
# epoch - 1: update step 48
# 390 - loss: 0.21637240052223206
# epoch - 1: update step 49
# 400 - loss: 0.08148248493671417
# epoch - 1: update step 50
# epoch - 1: update step 51
# 410 - loss: 0.08150622993707657
# epoch - 1: update step 52
# 420 - loss: 0.10962636023759842
# epoch - 1: update step 53
# 430 - loss: 0.09287045150995255
# epoch - 1: update step 54
# 440 - loss: 0.12706108391284943
# epoch - 1: update step 55
# epoch - 1: update step 56
# 450 - loss: 0.13889403641223907
# epoch - 1: update step 57
# 460 - loss: 0.24384528398513794
# epoch - 1: update step 58
# 470 - loss: 0.06494443863630295
# epoch - 1: update step 59
# 480 - loss: 0.14635911583900452
# epoch - 1: update step 60
# epoch - 1: update step 61
# 490 - loss: 0.1087629571557045
# epoch - 1: update step 62
# 500 - loss: 0.1453293412923813
# epoch - 1: update step 63
# 510 - loss: 0.16997526586055756
# epoch - 1: update step 64
# 520 - loss: 0.11651887744665146
# epoch - 1: update step 65
# epoch - 1: update step 66
# 530 - loss: 0.15249332785606384
# epoch - 1: update step 67
# 540 - loss: 0.0854606181383133
# epoch - 1: update step 68
# 550 - loss: 0.17815464735031128
# epoch - 1: update step 69
# 560 - loss: 0.09761013835668564
# epoch - 1: update step 70
# epoch - 1: update step 71
# 570 - loss: 0.07502377778291702
# epoch - 1: update step 72
# 580 - loss: 0.09109532833099365
# epoch - 1: update step 73
# 590 - loss: 0.0984686017036438
# epoch - 1: update step 74
# 600 - loss: 0.04342291131615639
# epoch - 1: update step 75
# epoch - 1: update step 76
# 610 - loss: 0.0843111053109169
# epoch - 1: update step 77
# 620 - loss: 0.1028953492641449
# epoch - 1: update step 78
# 630 - loss: 0.0313756950199604
# epoch - 1: update step 79
# 640 - loss: 0.08504433929920197
# epoch - 1: update step 80
# epoch - 1: update step 81
# 650 - loss: 0.28192058205604553
# epoch - 1: update step 82
# 660 - loss: 0.1238931193947792
# epoch - 1: update step 83
# 670 - loss: 0.04418478533625603
# epoch - 1: update step 84
# 680 - loss: 0.06441324949264526
# epoch - 1: update step 85
# epoch - 1: update step 86
# 690 - loss: 0.08649881184101105
# epoch - 1: update step 87
# 700 - loss: 0.1459193229675293
# epoch - 1: update step 88
# 710 - loss: 0.13208824396133423
# epoch - 1: update step 89
# 720 - loss: 0.13013841211795807
# epoch - 1: update step 90
# epoch - 1: update step 91
# 730 - loss: 0.13550646603107452
# epoch - 1: update step 92
# 740 - loss: 0.04201928526163101
# epoch - 1: update step 93
# 750 - loss: 0.1053975373506546
# epoch - 1: update step 94
# 760 - loss: 0.0849863663315773
# epoch - 1: update step 95
# epoch - 1: update step 96
# 770 - loss: 0.026980474591255188
# epoch - 1: update step 97
# 780 - loss: 0.08662071079015732
# epoch - 1: update step 98
# 790 - loss: 0.05250261723995209
# epoch - 1: update step 99
# 800 - loss: 0.1142752468585968
# epoch - 1: update step 100
# epoch - 1: update step 101
# 810 - loss: 0.09418225288391113
# epoch - 1: update step 102
# 820 - loss: 0.07850097864866257
# epoch - 1: update step 103
# 830 - loss: 0.17635366320610046
# epoch - 1: update step 104
# 840 - loss: 0.10365836322307587
# epoch - 1: update step 105
# epoch - 1: update step 106
# 850 - loss: 0.12316188216209412
# epoch - 1: update step 107
# 860 - loss: 0.07889711856842041
# epoch - 1: update step 108
# 870 - loss: 0.06361167132854462
# epoch - 1: update step 109
# 880 - loss: 0.10764899104833603
# epoch - 1: update step 110
# epoch - 1: update step 111
# 890 - loss: 0.17199555039405823
# epoch - 1: update step 112
# 900 - loss: 0.062424466013908386
# epoch - 1: update step 113
# 910 - loss: 0.14394421875476837
# epoch - 1: update step 114
# 920 - loss: 0.17400360107421875
# epoch - 1: update step 115
# epoch - 1: update step 116
# 930 - loss: 0.042389336973428726
# epoch - 1: update step 117
# epoch 1 END
# epoch - 2: update step 1
# 10 - loss: 0.10296124219894409
# epoch - 2: update step 2
# 20 - loss: 0.07624538242816925
# epoch - 2: update step 3
# 30 - loss: 0.09174750745296478
# epoch - 2: update step 4
# 40 - loss: 0.09452322125434875
# epoch - 2: update step 5
# epoch - 2: update step 6
# 50 - loss: 0.13044226169586182
# epoch - 2: update step 7
# 60 - loss: 0.23793509602546692
# epoch - 2: update step 8
# 70 - loss: 0.0878555178642273
# epoch - 2: update step 9
# 80 - loss: 0.06688106060028076
# epoch - 2: update step 10
# epoch - 2: update step 11
# 90 - loss: 0.09672527015209198
# epoch - 2: update step 12
# 100 - loss: 0.10850074142217636
# epoch - 2: update step 13
# 110 - loss: 0.07873751223087311
# epoch - 2: update step 14
# 120 - loss: 0.043164659291505814
# epoch - 2: update step 15
# epoch - 2: update step 16
# 130 - loss: 0.09892060607671738
# epoch - 2: update step 17
# 140 - loss: 0.06312982738018036
# epoch - 2: update step 18
# 150 - loss: 0.13081635534763336
# epoch - 2: update step 19
# 160 - loss: 0.04760025814175606
# epoch - 2: update step 20
# epoch - 2: update step 21
# 170 - loss: 0.0586102195084095
# epoch - 2: update step 22
# 180 - loss: 0.03238166496157646
# epoch - 2: update step 23
# 190 - loss: 0.07190543413162231
# epoch - 2: update step 24
# 200 - loss: 0.07991615682840347
# epoch - 2: update step 25
# epoch - 2: update step 26
# 210 - loss: 0.1302889585494995
# epoch - 2: update step 27
# 220 - loss: 0.0900668352842331
# epoch - 2: update step 28
# 230 - loss: 0.029406776651740074
# epoch - 2: update step 29
# 240 - loss: 0.16860535740852356
# epoch - 2: update step 30
# epoch - 2: update step 31
# 250 - loss: 0.06764111667871475
# epoch - 2: update step 32
# 260 - loss: 0.13241225481033325
# epoch - 2: update step 33
# 270 - loss: 0.11252877861261368
# epoch - 2: update step 34
# 280 - loss: 0.07863391935825348
# epoch - 2: update step 35
# epoch - 2: update step 36
# 290 - loss: 0.11548614501953125
# epoch - 2: update step 37
# 300 - loss: 0.17642298340797424
# epoch - 2: update step 38
# 310 - loss: 0.05853785574436188
# epoch - 2: update step 39
# 320 - loss: 0.035115960985422134
# epoch - 2: update step 40
# epoch - 2: update step 41
# 330 - loss: 0.047145944088697433
# epoch - 2: update step 42
# 340 - loss: 0.047304458916187286
# epoch - 2: update step 43
# 350 - loss: 0.06129955127835274
# epoch - 2: update step 44
# 360 - loss: 0.03915431722998619
# epoch - 2: update step 45
# epoch - 2: update step 46
# 370 - loss: 0.17338988184928894
# epoch - 2: update step 47
# 380 - loss: 0.053519148379564285
# epoch - 2: update step 48
# 390 - loss: 0.042045824229717255
# epoch - 2: update step 49
# 400 - loss: 0.056270964443683624
# epoch - 2: update step 50
# epoch - 2: update step 51
# 410 - loss: 0.12171453982591629
# epoch - 2: update step 52
# 420 - loss: 0.08014672994613647
# epoch - 2: update step 53
# 430 - loss: 0.027410460636019707
# epoch - 2: update step 54
# 440 - loss: 0.018873315304517746
# epoch - 2: update step 55
# epoch - 2: update step 56
# 450 - loss: 0.05957392603158951
# epoch - 2: update step 57
# 460 - loss: 0.0542304664850235
# epoch - 2: update step 58
# 470 - loss: 0.11495299637317657
# epoch - 2: update step 59
# 480 - loss: 0.050666093826293945
# epoch - 2: update step 60
# epoch - 2: update step 61
# 490 - loss: 0.06641935557126999
# epoch - 2: update step 62
# 500 - loss: 0.041101887822151184
# epoch - 2: update step 63
# 510 - loss: 0.13779695332050323
# epoch - 2: update step 64
# 520 - loss: 0.06264453381299973
# epoch - 2: update step 65
# epoch - 2: update step 66
# 530 - loss: 0.049458179622888565
# epoch - 2: update step 67
# 540 - loss: 0.03741947188973427
# epoch - 2: update step 68
# 550 - loss: 0.06044328585267067
# epoch - 2: update step 69
# 560 - loss: 0.09188499301671982
# epoch - 2: update step 70
# epoch - 2: update step 71
# 570 - loss: 0.055358294397592545
# epoch - 2: update step 72
# 580 - loss: 0.12260965257883072
# epoch - 2: update step 73
# 590 - loss: 0.08067575097084045
# epoch - 2: update step 74
# 600 - loss: 0.07632444053888321
# epoch - 2: update step 75
# epoch - 2: update step 76
# 610 - loss: 0.20697785913944244
# epoch - 2: update step 77
# 620 - loss: 0.1296728402376175
# epoch - 2: update step 78
# 630 - loss: 0.0775250792503357
# epoch - 2: update step 79
# 640 - loss: 0.09002869576215744
# epoch - 2: update step 80
# epoch - 2: update step 81
# 650 - loss: 0.014626484364271164
# epoch - 2: update step 82
# 660 - loss: 0.228347510099411
# epoch - 2: update step 83
# 670 - loss: 0.25426244735717773
# epoch - 2: update step 84
# 680 - loss: 0.07585779577493668
# epoch - 2: update step 85
# epoch - 2: update step 86
# 690 - loss: 0.1537647247314453
# epoch - 2: update step 87
# 700 - loss: 0.05124649405479431
# epoch - 2: update step 88
# 710 - loss: 0.07116737216711044
# epoch - 2: update step 89
# 720 - loss: 0.03166685253381729
# epoch - 2: update step 90
# epoch - 2: update step 91
# 730 - loss: 0.08868176490068436
# epoch - 2: update step 92
# 740 - loss: 0.027355091646313667
# epoch - 2: update step 93
# 750 - loss: 0.04189426824450493
# epoch - 2: update step 94
# 760 - loss: 0.11565393209457397
# epoch - 2: update step 95
# epoch - 2: update step 96
# 770 - loss: 0.01908998191356659
# epoch - 2: update step 97
# 780 - loss: 0.0633825957775116
# epoch - 2: update step 98
# 790 - loss: 0.04588446393609047
# epoch - 2: update step 99
# 800 - loss: 0.09706034511327744
# epoch - 2: update step 100
# epoch - 2: update step 101
# 810 - loss: 0.03081750124692917
# epoch - 2: update step 102
# 820 - loss: 0.14791257679462433
# epoch - 2: update step 103
# 830 - loss: 0.12300240993499756
# epoch - 2: update step 104
# 840 - loss: 0.2869082987308502
# epoch - 2: update step 105
# epoch - 2: update step 106
# 850 - loss: 0.05702092871069908
# epoch - 2: update step 107
# 860 - loss: 0.0835864320397377
# epoch - 2: update step 108
# 870 - loss: 0.16977104544639587
# epoch - 2: update step 109
# 880 - loss: 0.029951436445116997
# epoch - 2: update step 110
# epoch - 2: update step 111
# 890 - loss: 0.015761226415634155
# epoch - 2: update step 112
# 900 - loss: 0.039758700877428055
# epoch - 2: update step 113
# 910 - loss: 0.10786832869052887
# epoch - 2: update step 114
# 920 - loss: 0.02793329767882824
# epoch - 2: update step 115
# epoch - 2: update step 116
# 930 - loss: 0.016789112240076065
# epoch - 2: update step 117
# epoch 2 END
# epoch - 3: update step 1
# 10 - loss: 0.050755687057971954
# epoch - 3: update step 2
# 20 - loss: 0.07505044341087341
# epoch - 3: update step 3
# 30 - loss: 0.08862454444169998
# epoch - 3: update step 4
# 40 - loss: 0.030199093744158745
# epoch - 3: update step 5
# epoch - 3: update step 6
# 50 - loss: 0.08676805347204208
# epoch - 3: update step 7
# 60 - loss: 0.02882719598710537
# epoch - 3: update step 8
# 70 - loss: 0.3430691659450531
# epoch - 3: update step 9
# 80 - loss: 0.06266309320926666
# epoch - 3: update step 10
# epoch - 3: update step 11
# 90 - loss: 0.012516526505351067
# epoch - 3: update step 12
# 100 - loss: 0.11836723983287811
# epoch - 3: update step 13
# 110 - loss: 0.07360852509737015
# epoch - 3: update step 14
# 120 - loss: 0.041815925389528275
# epoch - 3: update step 15
# epoch - 3: update step 16
# 130 - loss: 0.06557001918554306
# epoch - 3: update step 17
# 140 - loss: 0.04703618586063385
# epoch - 3: update step 18
# 150 - loss: 0.033702220767736435
# epoch - 3: update step 19
# 160 - loss: 0.044652730226516724
# epoch - 3: update step 20
# epoch - 3: update step 21
# 170 - loss: 0.011229308322072029
# epoch - 3: update step 22
# 180 - loss: 0.008855191990733147
# epoch - 3: update step 23
# 190 - loss: 0.037390369921922684
# epoch - 3: update step 24
# 200 - loss: 0.043574556708335876
# epoch - 3: update step 25
# epoch - 3: update step 26
# 210 - loss: 0.07293279469013214
# epoch - 3: update step 27
# 220 - loss: 0.040970832109451294
# epoch - 3: update step 28
# 230 - loss: 0.0520625002682209
# epoch - 3: update step 29
# 240 - loss: 0.02662314847111702
# epoch - 3: update step 30
# epoch - 3: update step 31
# 250 - loss: 0.09058011323213577
# epoch - 3: update step 32
# 260 - loss: 0.03953416645526886
# epoch - 3: update step 33
# 270 - loss: 0.05983671545982361
# epoch - 3: update step 34
# 280 - loss: 0.010579549707472324
# epoch - 3: update step 35
# epoch - 3: update step 36
# 290 - loss: 0.10704638063907623
# epoch - 3: update step 37
# 300 - loss: 0.06673431396484375
# epoch - 3: update step 38
# 310 - loss: 0.048937682062387466
# epoch - 3: update step 39
# 320 - loss: 0.029111001640558243
# epoch - 3: update step 40
# epoch - 3: update step 41
# 330 - loss: 0.029242224991321564
# epoch - 3: update step 42
# 340 - loss: 0.08400343358516693
# epoch - 3: update step 43
# 350 - loss: 0.11996136605739594
# epoch - 3: update step 44
# 360 - loss: 0.05432092770934105
# epoch - 3: update step 45
# epoch - 3: update step 46
# 370 - loss: 0.06366076320409775
# epoch - 3: update step 47
# 380 - loss: 0.020801711827516556
# epoch - 3: update step 48
# 390 - loss: 0.0894869863986969
# epoch - 3: update step 49
# 400 - loss: 0.12869924306869507
# epoch - 3: update step 50
# epoch - 3: update step 51
# 410 - loss: 0.059054307639598846
# epoch - 3: update step 52
# 420 - loss: 0.10466239601373672
# epoch - 3: update step 53
# 430 - loss: 0.04633371904492378
# epoch - 3: update step 54
# 440 - loss: 0.06261305510997772
# epoch - 3: update step 55
# epoch - 3: update step 56
# 450 - loss: 0.022222286090254784
# epoch - 3: update step 57
# 460 - loss: 0.04455157369375229
# epoch - 3: update step 58
# 470 - loss: 0.011343996971845627
# epoch - 3: update step 59
# 480 - loss: 0.01960233971476555
# epoch - 3: update step 60
# epoch - 3: update step 61
# 490 - loss: 0.08605268597602844
# epoch - 3: update step 62
# 500 - loss: 0.05574113503098488
# epoch - 3: update step 63
# 510 - loss: 0.018302157521247864
# epoch - 3: update step 64
# 520 - loss: 0.20243903994560242
# epoch - 3: update step 65
# epoch - 3: update step 66
# 530 - loss: 0.021495673805475235
# epoch - 3: update step 67
# 540 - loss: 0.1293729841709137
# epoch - 3: update step 68
# 550 - loss: 0.04556257277727127
# epoch - 3: update step 69
# 560 - loss: 0.046034350991249084
# epoch - 3: update step 70
# epoch - 3: update step 71
# 570 - loss: 0.17112179100513458
# epoch - 3: update step 72
# 580 - loss: 0.10288318246603012
# epoch - 3: update step 73
# 590 - loss: 0.016282545402646065
# epoch - 3: update step 74
# 600 - loss: 0.09341146796941757
# epoch - 3: update step 75
# epoch - 3: update step 76
# 610 - loss: 0.03183537721633911
# epoch - 3: update step 77
# 620 - loss: 0.0623621866106987
# epoch - 3: update step 78
# 630 - loss: 0.11976755410432816
# epoch - 3: update step 79
# 640 - loss: 0.05032629892230034
# epoch - 3: update step 80
# epoch - 3: update step 81
# 650 - loss: 0.0749681293964386
# epoch - 3: update step 82
# 660 - loss: 0.023808680474758148
# epoch - 3: update step 83
# 670 - loss: 0.03656720742583275
# epoch - 3: update step 84
# 680 - loss: 0.3360639214515686
# epoch - 3: update step 85
# epoch - 3: update step 86
# 690 - loss: 0.01955680176615715
# epoch - 3: update step 87
# 700 - loss: 0.03790099918842316
# epoch - 3: update step 88
# 710 - loss: 0.08158820867538452
# epoch - 3: update step 89
# 720 - loss: 0.01589174009859562
# epoch - 3: update step 90
# epoch - 3: update step 91
# 730 - loss: 0.08466985821723938
# epoch - 3: update step 92
# 740 - loss: 0.09026253968477249
# epoch - 3: update step 93
# 750 - loss: 0.02516293153166771
# epoch - 3: update step 94
# 760 - loss: 0.008531348779797554
# epoch - 3: update step 95
# epoch - 3: update step 96
# 770 - loss: 0.0667288601398468
# epoch - 3: update step 97
# 780 - loss: 0.045019496232271194
# epoch - 3: update step 98
# 790 - loss: 0.04693501070141792
# epoch - 3: update step 99
# 800 - loss: 0.052454229444265366
# epoch - 3: update step 100
# epoch - 3: update step 101
# 810 - loss: 0.01845838688313961
# epoch - 3: update step 102
# 820 - loss: 0.027426837012171745
# epoch - 3: update step 103
# 830 - loss: 0.09174948185682297
# epoch - 3: update step 104
# 840 - loss: 0.046082753688097
# epoch - 3: update step 105
# epoch - 3: update step 106
# 850 - loss: 0.018490443006157875
# epoch - 3: update step 107
# 860 - loss: 0.025483528152108192
# epoch - 3: update step 108
# 870 - loss: 0.039783746004104614
# epoch - 3: update step 109
# 880 - loss: 0.025398554280400276
# epoch - 3: update step 110
# epoch - 3: update step 111
# 890 - loss: 0.06858193874359131
# epoch - 3: update step 112
# 900 - loss: 0.02761298231780529
# epoch - 3: update step 113
# 910 - loss: 0.10787256807088852
# epoch - 3: update step 114
# 920 - loss: 0.027570918202400208
# epoch - 3: update step 115
# epoch - 3: update step 116
# 930 - loss: 0.01020732894539833
# epoch - 3: update step 117
# epoch 3 END
# epoch - 4: update step 1
# 10 - loss: 0.03637146204710007
# epoch - 4: update step 2
# 20 - loss: 0.036792557686567307
# epoch - 4: update step 3
# 30 - loss: 0.04275999590754509
# epoch - 4: update step 4
# 40 - loss: 0.0684300884604454
# epoch - 4: update step 5
# epoch - 4: update step 6
# 50 - loss: 0.05227602273225784
# epoch - 4: update step 7
# 60 - loss: 0.008384853601455688
# epoch - 4: update step 8
# 70 - loss: 0.04662067070603371
# epoch - 4: update step 9
# 80 - loss: 0.11443225294351578
# epoch - 4: update step 10
# epoch - 4: update step 11
# 90 - loss: 0.05740944668650627
# epoch - 4: update step 12
# 100 - loss: 0.02018551714718342
# epoch - 4: update step 13
# 110 - loss: 0.03139202669262886
# epoch - 4: update step 14
# 120 - loss: 0.010513068176805973
# epoch - 4: update step 15
# epoch - 4: update step 16
# 130 - loss: 0.06558597087860107
# epoch - 4: update step 17
# 140 - loss: 0.022218452766537666
# epoch - 4: update step 18
# 150 - loss: 0.06169799715280533
# epoch - 4: update step 19
# 160 - loss: 0.01835879497230053
# epoch - 4: update step 20
# epoch - 4: update step 21
# 170 - loss: 0.01791071891784668
# epoch - 4: update step 22
# 180 - loss: 0.10743223875761032
# epoch - 4: update step 23
# 190 - loss: 0.04387657716870308
# epoch - 4: update step 24
# 200 - loss: 0.13284935057163239
# epoch - 4: update step 25
# epoch - 4: update step 26
# 210 - loss: 0.2000855803489685
# epoch - 4: update step 27
# 220 - loss: 0.010920509696006775
# epoch - 4: update step 28
# 230 - loss: 0.025714952498674393
# epoch - 4: update step 29
# 240 - loss: 0.032140109688043594
# epoch - 4: update step 30
# epoch - 4: update step 31
# 250 - loss: 0.02133255824446678
# epoch - 4: update step 32
# 260 - loss: 0.006606244947761297
# epoch - 4: update step 33
# 270 - loss: 0.02500661462545395
# epoch - 4: update step 34
# 280 - loss: 0.02497813105583191
# epoch - 4: update step 35
# epoch - 4: update step 36
# 290 - loss: 0.01079514715820551
# epoch - 4: update step 37
# 300 - loss: 0.018952932208776474
# epoch - 4: update step 38
# 310 - loss: 0.013630314730107784
# epoch - 4: update step 39
# 320 - loss: 0.032724857330322266
# epoch - 4: update step 40
# epoch - 4: update step 41
# 330 - loss: 0.096442312002182
# epoch - 4: update step 42
# 340 - loss: 0.06649205833673477
# epoch - 4: update step 43
# 350 - loss: 0.0556679293513298
# epoch - 4: update step 44
# 360 - loss: 0.02265346422791481
# epoch - 4: update step 45
# epoch - 4: update step 46
# 370 - loss: 0.04139573127031326
# epoch - 4: update step 47
# 380 - loss: 0.025796011090278625
# epoch - 4: update step 48
# 390 - loss: 0.01644088141620159
# epoch - 4: update step 49
# 400 - loss: 0.0651935264468193
# epoch - 4: update step 50
# epoch - 4: update step 51
# 410 - loss: 0.023577790707349777
# epoch - 4: update step 52
# 420 - loss: 0.012010390870273113
# epoch - 4: update step 53
# 430 - loss: 0.032036375254392624
# epoch - 4: update step 54
# 440 - loss: 0.02620774321258068
# epoch - 4: update step 55
# epoch - 4: update step 56
# 450 - loss: 0.006401795893907547
# epoch - 4: update step 57
# 460 - loss: 0.011677945032715797
# epoch - 4: update step 58
# 470 - loss: 0.013612993061542511
# epoch - 4: update step 59
# 480 - loss: 0.007976748049259186
# epoch - 4: update step 60
# epoch - 4: update step 61
# 490 - loss: 0.05593688413500786
# epoch - 4: update step 62
# 500 - loss: 0.0065341973677277565
# epoch - 4: update step 63
# 510 - loss: 0.023409433662891388
# epoch - 4: update step 64
# 520 - loss: 0.011801461689174175
# epoch - 4: update step 65
# epoch - 4: update step 66
# 530 - loss: 0.028374239802360535
# epoch - 4: update step 67
# 540 - loss: 0.006727041210979223
# epoch - 4: update step 68
# 550 - loss: 0.042149148881435394
# epoch - 4: update step 69
# 560 - loss: 0.014090996235609055
# epoch - 4: update step 70
# epoch - 4: update step 71
# 570 - loss: 0.0323692187666893
# epoch - 4: update step 72
# 580 - loss: 0.05720299482345581
# epoch - 4: update step 73
# 590 - loss: 0.007272668182849884
# epoch - 4: update step 74
# 600 - loss: 0.019089220091700554
# epoch - 4: update step 75
# epoch - 4: update step 76
# 610 - loss: 0.04302162677049637
# epoch - 4: update step 77
# 620 - loss: 0.06651943176984787
# epoch - 4: update step 78
# 630 - loss: 0.01121701579540968
# epoch - 4: update step 79
# 640 - loss: 0.017501087859272957
# epoch - 4: update step 80
# epoch - 4: update step 81
# 650 - loss: 0.006557106506079435
# epoch - 4: update step 82
# 660 - loss: 0.04572271183133125
# epoch - 4: update step 83
# 670 - loss: 0.05437520518898964
# epoch - 4: update step 84
# 680 - loss: 0.03846444934606552
# epoch - 4: update step 85
# epoch - 4: update step 86
# 690 - loss: 0.028140533715486526
# epoch - 4: update step 87
# 700 - loss: 0.0451032929122448
# epoch - 4: update step 88
# 710 - loss: 0.022899728268384933
# epoch - 4: update step 89
# 720 - loss: 0.05360651761293411
# epoch - 4: update step 90
# epoch - 4: update step 91
# 730 - loss: 0.038616444915533066
# epoch - 4: update step 92
# 740 - loss: 0.24862529337406158
# epoch - 4: update step 93
# 750 - loss: 0.010385727509856224
# epoch - 4: update step 94
# 760 - loss: 0.021733470261096954
# epoch - 4: update step 95
# epoch - 4: update step 96
# 770 - loss: 0.011703056283295155
# epoch - 4: update step 97
# 780 - loss: 0.0020614550448954105
# epoch - 4: update step 98
# 790 - loss: 0.06651436537504196
# epoch - 4: update step 99
# 800 - loss: 0.004556370433419943
# epoch - 4: update step 100
# epoch - 4: update step 101
# 810 - loss: 0.011708705686032772
# epoch - 4: update step 102
# 820 - loss: 0.004994343034923077
# epoch - 4: update step 103
# 830 - loss: 0.010795915499329567
# epoch - 4: update step 104
# 840 - loss: 0.05272989347577095
# epoch - 4: update step 105
# epoch - 4: update step 106
# 850 - loss: 0.052345164120197296
# epoch - 4: update step 107
# 860 - loss: 0.035781774669885635
# epoch - 4: update step 108
# 870 - loss: 0.06957376003265381
# epoch - 4: update step 109
# 880 - loss: 0.03807855769991875
# epoch - 4: update step 110
# epoch - 4: update step 111
# 890 - loss: 0.008733553811907768
# epoch - 4: update step 112
# 900 - loss: 0.0705728828907013
# epoch - 4: update step 113
# 910 - loss: 0.030642475932836533
# epoch - 4: update step 114
# 920 - loss: 0.07923462241888046
# epoch - 4: update step 115
# epoch - 4: update step 116
# 930 - loss: 0.008111818693578243
# epoch - 4: update step 117
# epoch 4 END

# %%
model.eval()

gold_list = []
pred_list = []

with torch.no_grad():
    for iteration, batch in enumerate(dataloader_test):
        batch_inputs = {k: v.cuda(device) for k, v in list(batch[0].items())}
        batch_labels = batch[1].cuda(device)
        
        output = model(**batch_inputs)
        loss = CELoss(output.view(-1, output.size(-1)), batch_labels.view(-1))
        
        print('loss:', loss.item())
        pred_ids = torch.argmax(output, dim=-1)
        
        for g, p in zip(batch_labels, pred_ids):
            gold_mask = g != tag_converter.pad_id
            
            gold = tag_converter.convert_id_to_tag_list(g[gold_mask].tolist())
            pred = tag_converter.convert_id_to_tag_list(p[gold_mask].tolist())
            gold_list.append(gold)
            pred_list.append(pred)
            
            print(f'GOLD:\t\t{gold}')
            print(f'PREDICTION:\t{pred}')
# Out:
# loss: 0.02454856038093567
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER']
# GOLD:		['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O']
# PREDICTION:	['O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O']
# GOLD:		['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O']
# loss: 0.028177984058856964
# GOLD:		['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O']
# PREDICTION:	['O', 'O']
# GOLD:		['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-LOC', 'O', 'B-LOC', 'O', 'B-LOC', 'I-LOC', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-LOC', 'O', 'B-LOC', 'O', 'B-LOC', 'I-LOC', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER']
# PREDICTION:	['B-LOC', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'B-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'B-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# loss: 0.02130773290991783
# GOLD:		['O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O']
# GOLD:		['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# loss: 0.08784755319356918
# GOLD:		['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O']
# PREDICTION:	['B-LOC', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC']
# PREDICTION:	['O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O']
# PREDICTION:	['O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
# loss: 0.008612719364464283
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O']
# PREDICTION:	['O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# loss: 0.03171573951840401
# GOLD:		['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-MISC', 'I-MISC', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O']
# PREDICTION:	['B-LOC', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O']
# PREDICTION:	['O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# loss: 0.03120732493698597
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O']
# GOLD:		['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'B-LOC', 'I-LOC', 'I-LOC']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'B-LOC', 'I-LOC', 'I-LOC']
# GOLD:		['O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'I-LOC']
# PREDICTION:	['B-LOC', 'I-LOC']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-ORG', 'I-PER', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'O', 'O']
# loss: 0.01912575401365757
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'I-LOC', 'O', 'O']
# PREDICTION:	['B-LOC', 'I-LOC', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'O']
# loss: 0.0019481983035802841
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER']
# PREDICTION:	['O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O']
# loss: 0.08846742659807205
# GOLD:		['O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC']
# PREDICTION:	['O', 'O', 'O', 'O', 'B-MISC', 'B-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC']
# GOLD:		['B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'O', 'B-ORG', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'B-ORG', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-MISC', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-MISC', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O']
# GOLD:		['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# loss: 0.06637109816074371
# GOLD:		['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'I-MISC']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'I-MISC']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# loss: 0.043749116361141205
# GOLD:		['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# loss: 0.14936478435993195
# GOLD:		['O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ...
# PREDICTION:	['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-MISC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# loss: 0.13194777071475983
# GOLD:		['B-MISC', 'B-PER', 'I-PER', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-MISC', 'B-PER', 'I-PER', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'B-ORG', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'B-ORG', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'B-MISC', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'B-MISC', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'B-PER', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'B-PER', 'O', 'O']
# loss: 0.10144682973623276
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-MISC', 'O', 'B-PER', 'O', 'B-MISC', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-MISC', 'O', 'B-PER', 'O', 'B-MISC', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-MISC', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'B-MISC', 'O', 'B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O']
# GOLD:		['O', 'B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC']
# GOLD:		['O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'O', 'B-ORG', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'O', 'B-ORG', 'O', 'O']
# loss: 0.0037663786206394434
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# loss: 0.13486556708812714
# GOLD:		['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'I-MISC', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'B-MISC', 'I-LOC', 'I-LOC', 'I-LOC', 'I-MISC', 'I-MISC', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O']
# GOLD:		['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O']
# loss: 0.057314638048410416
# GOLD:		['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['B-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['B-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'B-LOC', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# PREDICTION:	['O', 'O', 'B-LOC', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# GOLD:		['O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O']
# PREDICTION:	['O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O']

# %%
gold_list_flat = []
pred_list_flat = []
for g, p in zip(gold_list, pred_list):
    gold_list_flat += g
    pred_list_flat += p

# %%
test_tag_list = []

with open ('../data/en_ner_data/prepro_test_tag_list.json', 'r') as f:
	test_tag_list = json.load(f)

test_tag_list
# Out:
# ['B-ORG', 'I-PER', 'I-MISC', 'B-MISC', 'I-ORG', 'B-PER', 'O', 'B-LOC', 'I-LOC']

# %%
tags = test_tag_list
tags.remove('O')
print(tags)
# Out:
# ['B-ORG', 'I-PER', 'I-MISC', 'B-MISC', 'I-ORG', 'B-PER', 'B-LOC', 'I-LOC']

# %%
print(classification_report(gold_list_flat, pred_list_flat, digits=5, labels=tags))
# Out:
#               precision    recall  f1-score   support
#
#        B-ORG    0.89110   0.89333   0.89221      1603
#        I-PER    0.95146   0.97013   0.96071      3415
#       I-MISC    0.58112   0.64395   0.61093       851
#       B-MISC    0.78854   0.83165   0.80952       695
#        I-ORG    0.90057   0.91298   0.90673      2758
#        B-PER    0.94909   0.95812   0.95358      1576
#        B-LOC    0.90958   0.92735   0.91838      1638
#        I-LOC    0.86161   0.92179   0.89068      1675
#
#    micro avg    0.88696   0.91211   0.89936     14211
#    macro avg    0.85413   0.88241   0.86784     14211
# weighted avg    0.88895   0.91211   0.90024     14211

# %%
def get_chunk_type(tag_name):
    tag_class = tag_name.split('-')[0]
    tag_type = tag_name.split('-')[-1]
    return tag_class, tag_type

# %%
def get_chunks(seq):
    default = "O"

    chunks = []
    chunk_type, chunk_start = None, None
    for i, tok in enumerate(seq):
        # End of a chunk 1
        if tok == default and chunk_type is not None:
            # Add a chunk.
            chunk = (chunk_type, chunk_start, i)
            chunks.append(chunk)
            chunk_type, chunk_start = None, None

        # End of a chunk + start of a chunk!
        elif tok != default:
            tok_chunk_class, tok_chunk_type = get_chunk_type(tok)
            if chunk_type is None:
                chunk_type, chunk_start = tok_chunk_type, i
            elif tok_chunk_type != chunk_type or tok_chunk_class == "B":
                chunk = (chunk_type, chunk_start, i)
                chunks.append(chunk)
                chunk_type, chunk_start = tok_chunk_type, i
        else:
            pass

    # end condition
    if chunk_type is not None:
        chunk = (chunk_type, chunk_start, len(seq))
        chunks.append(chunk)

    return chunks

# %%
def evaluate_ner_F1(total_answers, total_preds):
    num_match = num_preds = num_answers = 0

    for answers, preds in zip(total_answers, total_preds):

        answer_seg_result = set(get_chunks(answers))
        pred_seg_result = set(get_chunks(preds))

        num_match += len(answer_seg_result & pred_seg_result)
        num_answers += len(answer_seg_result)
        num_preds += len(pred_seg_result)

    precision = 100.0 * num_match / num_preds
    recall = 100.0 * num_match / num_answers
    F1 = 2 * precision * recall / (precision + recall)

    return precision, recall, F1

# %%
evaluate_ner_F1(gold_list, pred_list)
# Out:
# (86.70045438657812, 90.00362844702467, 88.32116788321167)

# %%
torch.save(model, '../model/model.pt')

# %%
torch.save(model.state_dict(), '../model/model_state_dict.pt')
